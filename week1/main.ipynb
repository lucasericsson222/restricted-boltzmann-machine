# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
plt.title("Gibbs Sampling Resulting Distribution, 10000 samples, 5 length MC")
plt.ylabel('Probability')
plt.xlabel('Visible State')
plt.bar([0,1,2,3,4,5,6,7], [0.1885, 0.0742, 0.2453, 0.0042, 0.1074, 0.0035, 0.0076, 0.3693])
plt.xticks([0,1,2,3,4,5,6,7],['000', '001', '010', '011', '100', '101', '110', '111'])
plt.show()

# %%
plt.title("Brute Force Method and Sigmoid Method")
plt.bar([0,1,2,3,4,5,6,7], [0.32562304384297674, 0.00595124312515659, 0.3241381585218917, 0.0009118478603581222, 0.002281098569053033, 0.0010861251440600357, 0.021815400913982853, 0.3181930820225209])
plt.ylabel('Probability')
plt.xlabel('Visible State')
plt.xticks([0,1,2,3,4,5,6,7],['000', '001', '010', '011', '100', '101', '110', '111'])
plt.show()

# %% [markdown]
# There's something weird going on with the difference in the graphs here, but I haven't yet figured out the mistake. It looks like the Gibbs sampling method was more accurate to what I expected, so I'm currently looking for flaws in the Brute Force Method.
